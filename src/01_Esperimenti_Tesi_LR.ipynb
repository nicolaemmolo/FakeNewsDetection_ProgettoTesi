# %% [markdown]
# # **LOGISTIC REGRESSION**

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1" # "0" o "1"

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
from utils import *

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, f1_score, confusion_matrix

# %%
# -----------------------
# Model building function
# -----------------------

def build_model(C=1.0, penalty="l2", solver="lbfgs"):
    """
    Builds a scikit-learn Pipeline with TF-IDF vectorization and Logistic Regression classifier.

    Args:
        C (float): Inverse of regularization strength for Logistic Regression.
        penalty (str): Regularization type for Logistic Regression
        solver (str): Solver to use for Logistic Regression.

    Returns:
        Pipeline: A scikit-learn Pipeline object (TF-IDF + Logistic Regression).
    """
    
    return Pipeline([
        ('tfidf', TfidfVectorizer(  # TD-IDF vectorization
            max_features=5000,      # limit to top 5000 features
            ngram_range=(1, 2),     # unigrams + bigrams
            stop_words="english"    # remove English stop words
        )),
        ('clf', LogisticRegression( # Logistic Regression classifier
            C=C,
            penalty=penalty if penalty != "none" else None,
            solver=solver,
            max_iter=1000,
            random_state=42,
        ))
    ])

# %% [markdown]
# ## VERSION 1: Dataset (Simple)

# %%
# --------------------------------
# Fine-tuning on multiple datasets
# --------------------------------

datasets_df = data_loading() # load datasets

datasets = {name: split_dataset(df) for name, df in datasets_df.items()} # split all datasets in train/val/test
model = build_model() # initialize model

results = {}

# sequential training
for i, (name, data) in enumerate(datasets.items()):
    print(f"\n=== Phase {i+1}: Training/Fine-tuning on {name} ===")
    
    X_train, y_train = data["train"]
    X_val, y_val = data["val"]
    X_test, y_test = data["test"]

    model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val])) # fine-tune on train + val

    y_pred = model.predict(X_test)
    print(f"Classification Report after {name}:")
    print(classification_report(y_test, y_pred))
    print(f"Confusion Matrix after {name}:")
    print(confusion_matrix(y_test, y_pred))
    print(f"\nWeighted F1-score after {name}:", f1_score(y_test, y_pred, average="weighted"))


    # evaluation on all datasets
    print("\n--- Evaluation on all datasets ---")
    results[name] = {}
    for test_name, test_data in datasets.items(): # for each dataset
        X_te, y_te = test_data["test"]
        preds = model.predict(X_te)
        f1 = f1_score(y_te, preds, average="weighted")
        results[name][test_name] = f1
        print(f"Evaluation on {test_name}: Weighted F1 = {f1:.4f}")
# Out:
# /home/n.emmolo/progetto_tesi/src/utils.py:162: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   dfKaggleMeg['date'] = pd.to_datetime(dfKaggleMeg['date'], errors='coerce') # convert date column to datetime, coerce errors to NaT
# === Phase 1: Training/Fine-tuning on Celebrity ===
# Classification Report after Celebrity:
#               precision    recall  f1-score   support
#
#            0       0.65      0.84      0.73        50
#            1       0.77      0.54      0.64        50
#
#     accuracy                           0.69       100
#    macro avg       0.71      0.69      0.68       100
# weighted avg       0.71      0.69      0.68       100
#
# Confusion Matrix after Celebrity:
# [[42  8]
#  [23 27]]
#
# Weighted F1-score after Celebrity: 0.6828644501278772
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.6829
# Evaluation on CIDII: Weighted F1 = 0.5762
# Evaluation on FaKES: Weighted F1 = 0.4241
# Evaluation on FakeVsSatire: Weighted F1 = 0.3143
# Evaluation on Horne: Weighted F1 = 0.5014
# Evaluation on Infodemic: Weighted F1 = 0.5466
# Evaluation on ISOT: Weighted F1 = 0.3799
# Evaluation on Kaggle_clement: Weighted F1 = 0.4266
# Evaluation on Kaggle_meg: Weighted F1 = 0.8955
# Evaluation on LIAR_PLUS: Weighted F1 = 0.5316
# Evaluation on Politifact: Weighted F1 = 0.6230
# Evaluation on Unipi_NDF: Weighted F1 = 0.5003
#
# === Phase 2: Training/Fine-tuning on CIDII ===
# Classification Report after CIDII:
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90        85
#            1       0.96      0.73      0.83        60
#
#     accuracy                           0.88       145
#    macro avg       0.90      0.85      0.87       145
# weighted avg       0.89      0.88      0.87       145
#
# Confusion Matrix after CIDII:
# [[83  2]
#  [16 44]]
#
# Weighted F1-score after CIDII: 0.8723869197476734
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4415
# Evaluation on CIDII: Weighted F1 = 0.8724
# Evaluation on FaKES: Weighted F1 = 0.3764
# Evaluation on FakeVsSatire: Weighted F1 = 0.3192
# Evaluation on Horne: Weighted F1 = 0.5775
# Evaluation on Infodemic: Weighted F1 = 0.4860
# Evaluation on ISOT: Weighted F1 = 0.4455
# Evaluation on Kaggle_clement: Weighted F1 = 0.5040
# Evaluation on Kaggle_meg: Weighted F1 = 0.9043
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4556
# Evaluation on Politifact: Weighted F1 = 0.6054
# Evaluation on Unipi_NDF: Weighted F1 = 0.6775
#
# === Phase 3: Training/Fine-tuning on FaKES ===
# Classification Report after FaKES:
#               precision    recall  f1-score   support
#
#            0       0.56      0.76      0.65        89
#            1       0.56      0.34      0.42        80
#
#     accuracy                           0.56       169
#    macro avg       0.56      0.55      0.53       169
# weighted avg       0.56      0.56      0.54       169
#
# Confusion Matrix after FaKES:
# [[68 21]
#  [53 27]]
#
# Weighted F1-score after FaKES: 0.5407579599887292
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3686
# Evaluation on CIDII: Weighted F1 = 0.4977
# Evaluation on FaKES: Weighted F1 = 0.5408
# Evaluation on FakeVsSatire: Weighted F1 = 0.2898
# Evaluation on Horne: Weighted F1 = 0.5307
# Evaluation on Infodemic: Weighted F1 = 0.4614
# Evaluation on ISOT: Weighted F1 = 0.3492
# Evaluation on Kaggle_clement: Weighted F1 = 0.3809
# Evaluation on Kaggle_meg: Weighted F1 = 0.8929
# Evaluation on LIAR_PLUS: Weighted F1 = 0.5023
# Evaluation on Politifact: Weighted F1 = 0.4319
# Evaluation on Unipi_NDF: Weighted F1 = 0.4558
#
# === Phase 4: Training/Fine-tuning on FakeVsSatire ===
# Classification Report after FakeVsSatire:
#               precision    recall  f1-score   support
#
#            0       0.88      0.37      0.52        41
#            1       0.68      0.96      0.80        57
#
#     accuracy                           0.71        98
#    macro avg       0.78      0.67      0.66        98
# weighted avg       0.76      0.71      0.68        98
#
# Confusion Matrix after FakeVsSatire:
# [[15 26]
#  [ 2 55]]
#
# Weighted F1-score after FakeVsSatire: 0.6800171342899978
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4110
# Evaluation on CIDII: Weighted F1 = 0.2422
# Evaluation on FaKES: Weighted F1 = 0.3042
# Evaluation on FakeVsSatire: Weighted F1 = 0.6800
# Evaluation on Horne: Weighted F1 = 0.4110
# Evaluation on Infodemic: Weighted F1 = 0.3095
# Evaluation on ISOT: Weighted F1 = 0.4184
# Evaluation on Kaggle_clement: Weighted F1 = 0.3608
# Evaluation on Kaggle_meg: Weighted F1 = 0.0907
# Evaluation on LIAR_PLUS: Weighted F1 = 0.2931
# Evaluation on Politifact: Weighted F1 = 0.2104
# Evaluation on Unipi_NDF: Weighted F1 = 0.2316
#
# === Phase 5: Training/Fine-tuning on Horne ===
# Classification Report after Horne:
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80        41
#            1       1.00      0.16      0.28        25
#
#     accuracy                           0.68        66
#    macro avg       0.83      0.58      0.54        66
# weighted avg       0.79      0.68      0.60        66
#
# Confusion Matrix after Horne:
# [[41  0]
#  [21  4]]
#
# Weighted F1-score after Horne: 0.5990504306540463
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3333
# Evaluation on CIDII: Weighted F1 = 0.4487
# Evaluation on FaKES: Weighted F1 = 0.3773
# Evaluation on FakeVsSatire: Weighted F1 = 0.2687
# Evaluation on Horne: Weighted F1 = 0.5991
# Evaluation on Infodemic: Weighted F1 = 0.3640
# Evaluation on ISOT: Weighted F1 = 0.3421
# Evaluation on Kaggle_clement: Weighted F1 = 0.4049
# Evaluation on Kaggle_meg: Weighted F1 = 0.9522
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4172
# Evaluation on Politifact: Weighted F1 = 0.5419
# Evaluation on Unipi_NDF: Weighted F1 = 0.4810
#
# === Phase 6: Training/Fine-tuning on Infodemic ===
# Classification Report after Infodemic:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94      1106
#          1.0       0.94      0.94      0.94      1006
#
#     accuracy                           0.94      2112
#    macro avg       0.94      0.94      0.94      2112
# weighted avg       0.94      0.94      0.94      2112
#
# Confusion Matrix after Infodemic:
# [[1041   65]
#  [  62  944]]
#
# Weighted F1-score after Infodemic: 0.939871355504798
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3929
# Evaluation on CIDII: Weighted F1 = 0.2892
# Evaluation on FaKES: Weighted F1 = 0.3363
# Evaluation on FakeVsSatire: Weighted F1 = 0.4452
# Evaluation on Horne: Weighted F1 = 0.2918
# Evaluation on Infodemic: Weighted F1 = 0.9399
# Evaluation on ISOT: Weighted F1 = 0.3934
# Evaluation on Kaggle_clement: Weighted F1 = 0.3356
# Evaluation on Kaggle_meg: Weighted F1 = 0.1997
# Evaluation on LIAR_PLUS: Weighted F1 = 0.3833
# Evaluation on Politifact: Weighted F1 = 0.3725
# Evaluation on Unipi_NDF: Weighted F1 = 0.4123
#
# === Phase 7: Training/Fine-tuning on ISOT ===
# Classification Report after ISOT:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4284
#            1       0.99      0.99      0.99      4571
#
#     accuracy                           0.99      8855
#    macro avg       0.99      0.99      0.99      8855
# weighted avg       0.99      0.99      0.99      8855
#
# Confusion Matrix after ISOT:
# [[4261   23]
#  [  52 4519]]
#
# Weighted F1-score after ISOT: 0.9915310177978018
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3967
# Evaluation on CIDII: Weighted F1 = 0.2997
# Evaluation on FaKES: Weighted F1 = 0.4612
# Evaluation on FakeVsSatire: Weighted F1 = 0.4552
# Evaluation on Horne: Weighted F1 = 0.5940
# Evaluation on Infodemic: Weighted F1 = 0.3033
# Evaluation on ISOT: Weighted F1 = 0.9915
# Evaluation on Kaggle_clement: Weighted F1 = 0.9905
# Evaluation on Kaggle_meg: Weighted F1 = 0.0997
# Evaluation on LIAR_PLUS: Weighted F1 = 0.3048
# Evaluation on Politifact: Weighted F1 = 0.3111
# Evaluation on Unipi_NDF: Weighted F1 = 0.2316
#
# === Phase 8: Training/Fine-tuning on Kaggle_clement ===
# Classification Report after Kaggle_clement:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      4240
#            1       0.99      0.98      0.99      3581
#
#     accuracy                           0.99      7821
#    macro avg       0.99      0.99      0.99      7821
# weighted avg       0.99      0.99      0.99      7821
#
# Confusion Matrix after Kaggle_clement:
# [[4218   22]
#  [  65 3516]]
#
# Weighted F1-score after Kaggle_clement: 0.9888705686485378
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3912
# Evaluation on CIDII: Weighted F1 = 0.4258
# Evaluation on FaKES: Weighted F1 = 0.4577
# Evaluation on FakeVsSatire: Weighted F1 = 0.4399
# Evaluation on Horne: Weighted F1 = 0.4437
# Evaluation on Infodemic: Weighted F1 = 0.3139
# Evaluation on ISOT: Weighted F1 = 0.9849
# Evaluation on Kaggle_clement: Weighted F1 = 0.9889
# Evaluation on Kaggle_meg: Weighted F1 = 0.1488
# Evaluation on LIAR_PLUS: Weighted F1 = 0.3946
# Evaluation on Politifact: Weighted F1 = 0.3570
# Evaluation on Unipi_NDF: Weighted F1 = 0.2635
#
# === Phase 9: Training/Fine-tuning on Kaggle_meg ===
# Classification Report after Kaggle_meg:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      2514
#            1       1.00      0.02      0.04        55
#
#     accuracy                           0.98      2569
#    macro avg       0.99      0.51      0.51      2569
# weighted avg       0.98      0.98      0.97      2569
#
# Confusion Matrix after Kaggle_meg:
# [[2514    0]
#  [  54    1]]
#
# Weighted F1-score after Kaggle_meg: 0.9689572520971367
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3333
# Evaluation on CIDII: Weighted F1 = 0.4333
# Evaluation on FaKES: Weighted F1 = 0.3633
# Evaluation on FakeVsSatire: Weighted F1 = 0.2468
# Evaluation on Horne: Weighted F1 = 0.4761
# Evaluation on Infodemic: Weighted F1 = 0.3600
# Evaluation on ISOT: Weighted F1 = 0.3155
# Evaluation on Kaggle_clement: Weighted F1 = 0.3812
# Evaluation on Kaggle_meg: Weighted F1 = 0.9690
# Evaluation on LIAR_PLUS: Weighted F1 = 0.3993
# Evaluation on Politifact: Weighted F1 = 0.5040
# Evaluation on Unipi_NDF: Weighted F1 = 0.4654
#
# === Phase 10: Training/Fine-tuning on LIAR_PLUS ===
# Classification Report after LIAR_PLUS:
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.73      0.67      1426
#          1.0       0.56      0.44      0.49      1131
#
#     accuracy                           0.60      2557
#    macro avg       0.59      0.58      0.58      2557
# weighted avg       0.59      0.60      0.59      2557
#
# Confusion Matrix after LIAR_PLUS:
# [[1037  389]
#  [ 638  493]]
#
# Weighted F1-score after LIAR_PLUS: 0.5896419478488236
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.5100
# Evaluation on CIDII: Weighted F1 = 0.4435
# Evaluation on FaKES: Weighted F1 = 0.5418
# Evaluation on FakeVsSatire: Weighted F1 = 0.6027
# Evaluation on Horne: Weighted F1 = 0.5522
# Evaluation on Infodemic: Weighted F1 = 0.5819
# Evaluation on ISOT: Weighted F1 = 0.5630
# Evaluation on Kaggle_clement: Weighted F1 = 0.5736
# Evaluation on Kaggle_meg: Weighted F1 = 0.7298
# Evaluation on LIAR_PLUS: Weighted F1 = 0.5896
# Evaluation on Politifact: Weighted F1 = 0.6786
# Evaluation on Unipi_NDF: Weighted F1 = 0.4572
#
# === Phase 11: Training/Fine-tuning on Politifact ===
# Classification Report after Politifact:
#               precision    recall  f1-score   support
#
#            0       0.74      0.98      0.85        65
#            1       0.93      0.39      0.55        36
#
#     accuracy                           0.77       101
#    macro avg       0.84      0.69      0.70       101
# weighted avg       0.81      0.77      0.74       101
#
# Confusion Matrix after Politifact:
# [[64  1]
#  [22 14]]
#
# Weighted F1-score after Politifact: 0.7412281547593793
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3628
# Evaluation on CIDII: Weighted F1 = 0.4333
# Evaluation on FaKES: Weighted F1 = 0.3606
# Evaluation on FakeVsSatire: Weighted F1 = 0.3878
# Evaluation on Horne: Weighted F1 = 0.5806
# Evaluation on Infodemic: Weighted F1 = 0.4337
# Evaluation on ISOT: Weighted F1 = 0.5055
# Evaluation on Kaggle_clement: Weighted F1 = 0.5655
# Evaluation on Kaggle_meg: Weighted F1 = 0.9265
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4120
# Evaluation on Politifact: Weighted F1 = 0.7412
# Evaluation on Unipi_NDF: Weighted F1 = 0.4849
#
# === Phase 12: Training/Fine-tuning on Unipi_NDF ===
# Classification Report after Unipi_NDF:
#               precision    recall  f1-score   support
#
#            0       0.79      0.96      0.87        68
#            1       0.90      0.60      0.72        43
#
#     accuracy                           0.82       111
#    macro avg       0.84      0.78      0.79       111
# weighted avg       0.83      0.82      0.81       111
#
# Confusion Matrix after Unipi_NDF:
# [[65  3]
#  [17 26]]
#
# Weighted F1-score after Unipi_NDF: 0.8107107107107108
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.5536
# Evaluation on CIDII: Weighted F1 = 0.3603
# Evaluation on FaKES: Weighted F1 = 0.3333
# Evaluation on FakeVsSatire: Weighted F1 = 0.5175
# Evaluation on Horne: Weighted F1 = 0.3891
# Evaluation on Infodemic: Weighted F1 = 0.5859
# Evaluation on ISOT: Weighted F1 = 0.4038
# Evaluation on Kaggle_clement: Weighted F1 = 0.3864
# Evaluation on Kaggle_meg: Weighted F1 = 0.5329
# Evaluation on LIAR_PLUS: Weighted F1 = 0.5102
# Evaluation on Politifact: Weighted F1 = 0.5247
# Evaluation on Unipi_NDF: Weighted F1 = 0.8107

# %%
# ---------------
# Results summary
# ---------------

print("\n=== Results Summary ===")
for name, res in results.items():
    print(f"\nResults after training on {name}:")
    for test_name, f1 in res.items():
        print(f"  Test on {test_name}: Weighted F1 = {f1:.4f}")
# Out:
# === Results Summary ===
#
# Results after training on Celebrity:
#   Test on Celebrity: Weighted F1 = 0.6829
#   Test on CIDII: Weighted F1 = 0.5762
#   Test on FaKES: Weighted F1 = 0.4241
#   Test on FakeVsSatire: Weighted F1 = 0.3143
#   Test on Horne: Weighted F1 = 0.5014
#   Test on Infodemic: Weighted F1 = 0.5466
#   Test on ISOT: Weighted F1 = 0.3799
#   Test on Kaggle_clement: Weighted F1 = 0.4266
#   Test on Kaggle_meg: Weighted F1 = 0.8955
#   Test on LIAR_PLUS: Weighted F1 = 0.5316
#   Test on Politifact: Weighted F1 = 0.6230
#   Test on Unipi_NDF: Weighted F1 = 0.5003
#
# Results after training on CIDII:
#   Test on Celebrity: Weighted F1 = 0.4415
#   Test on CIDII: Weighted F1 = 0.8724
#   Test on FaKES: Weighted F1 = 0.3764
#   Test on FakeVsSatire: Weighted F1 = 0.3192
#   Test on Horne: Weighted F1 = 0.5775
#   Test on Infodemic: Weighted F1 = 0.4860
#   Test on ISOT: Weighted F1 = 0.4455
#   Test on Kaggle_clement: Weighted F1 = 0.5040
#   Test on Kaggle_meg: Weighted F1 = 0.9043
#   Test on LIAR_PLUS: Weighted F1 = 0.4556
#   Test on Politifact: Weighted F1 = 0.6054
#   Test on Unipi_NDF: Weighted F1 = 0.6775
#
# Results after training on FaKES:
#   Test on Celebrity: Weighted F1 = 0.3686
#   Test on CIDII: Weighted F1 = 0.4977
#   Test on FaKES: Weighted F1 = 0.5408
#   Test on FakeVsSatire: Weighted F1 = 0.2898
#   Test on Horne: Weighted F1 = 0.5307
#   Test on Infodemic: Weighted F1 = 0.4614
#   Test on ISOT: Weighted F1 = 0.3492
#   Test on Kaggle_clement: Weighted F1 = 0.3809
#   Test on Kaggle_meg: Weighted F1 = 0.8929
#   Test on LIAR_PLUS: Weighted F1 = 0.5023
#   Test on Politifact: Weighted F1 = 0.4319
#   Test on Unipi_NDF: Weighted F1 = 0.4558
#
# Results after training on FakeVsSatire:
#   Test on Celebrity: Weighted F1 = 0.4110
#   Test on CIDII: Weighted F1 = 0.2422
#   Test on FaKES: Weighted F1 = 0.3042
#   Test on FakeVsSatire: Weighted F1 = 0.6800
#   Test on Horne: Weighted F1 = 0.4110
#   Test on Infodemic: Weighted F1 = 0.3095
#   Test on ISOT: Weighted F1 = 0.4184
#   Test on Kaggle_clement: Weighted F1 = 0.3608
#   Test on Kaggle_meg: Weighted F1 = 0.0907
#   Test on LIAR_PLUS: Weighted F1 = 0.2931
#   Test on Politifact: Weighted F1 = 0.2104
#   Test on Unipi_NDF: Weighted F1 = 0.2316
#
# Results after training on Horne:
#   Test on Celebrity: Weighted F1 = 0.3333
#   Test on CIDII: Weighted F1 = 0.4487
#   Test on FaKES: Weighted F1 = 0.3773
#   Test on FakeVsSatire: Weighted F1 = 0.2687
#   Test on Horne: Weighted F1 = 0.5991
#   Test on Infodemic: Weighted F1 = 0.3640
#   Test on ISOT: Weighted F1 = 0.3421
#   Test on Kaggle_clement: Weighted F1 = 0.4049
#   Test on Kaggle_meg: Weighted F1 = 0.9522
#   Test on LIAR_PLUS: Weighted F1 = 0.4172
#   Test on Politifact: Weighted F1 = 0.5419
#   Test on Unipi_NDF: Weighted F1 = 0.4810
#
# Results after training on Infodemic:
#   Test on Celebrity: Weighted F1 = 0.3929
#   Test on CIDII: Weighted F1 = 0.2892
#   Test on FaKES: Weighted F1 = 0.3363
#   Test on FakeVsSatire: Weighted F1 = 0.4452
#   Test on Horne: Weighted F1 = 0.2918
#   Test on Infodemic: Weighted F1 = 0.9399
#   Test on ISOT: Weighted F1 = 0.3934
#   Test on Kaggle_clement: Weighted F1 = 0.3356
#   Test on Kaggle_meg: Weighted F1 = 0.1997
#   Test on LIAR_PLUS: Weighted F1 = 0.3833
#   Test on Politifact: Weighted F1 = 0.3725
#   Test on Unipi_NDF: Weighted F1 = 0.4123
#
# Results after training on ISOT:
#   Test on Celebrity: Weighted F1 = 0.3967
#   Test on CIDII: Weighted F1 = 0.2997
#   Test on FaKES: Weighted F1 = 0.4612
#   Test on FakeVsSatire: Weighted F1 = 0.4552
#   Test on Horne: Weighted F1 = 0.5940
#   Test on Infodemic: Weighted F1 = 0.3033
#   Test on ISOT: Weighted F1 = 0.9915
#   Test on Kaggle_clement: Weighted F1 = 0.9905
#   Test on Kaggle_meg: Weighted F1 = 0.0997
#   Test on LIAR_PLUS: Weighted F1 = 0.3048
#   Test on Politifact: Weighted F1 = 0.3111
#   Test on Unipi_NDF: Weighted F1 = 0.2316
#
# Results after training on Kaggle_clement:
#   Test on Celebrity: Weighted F1 = 0.3912
#   Test on CIDII: Weighted F1 = 0.4258
#   Test on FaKES: Weighted F1 = 0.4577
#   Test on FakeVsSatire: Weighted F1 = 0.4399
#   Test on Horne: Weighted F1 = 0.4437
#   Test on Infodemic: Weighted F1 = 0.3139
#   Test on ISOT: Weighted F1 = 0.9849
#   Test on Kaggle_clement: Weighted F1 = 0.9889
#   Test on Kaggle_meg: Weighted F1 = 0.1488
#   Test on LIAR_PLUS: Weighted F1 = 0.3946
#   Test on Politifact: Weighted F1 = 0.3570
#   Test on Unipi_NDF: Weighted F1 = 0.2635
#
# Results after training on Kaggle_meg:
#   Test on Celebrity: Weighted F1 = 0.3333
#   Test on CIDII: Weighted F1 = 0.4333
#   Test on FaKES: Weighted F1 = 0.3633
#   Test on FakeVsSatire: Weighted F1 = 0.2468
#   Test on Horne: Weighted F1 = 0.4761
#   Test on Infodemic: Weighted F1 = 0.3600
#   Test on ISOT: Weighted F1 = 0.3155
#   Test on Kaggle_clement: Weighted F1 = 0.3812
#   Test on Kaggle_meg: Weighted F1 = 0.9690
#   Test on LIAR_PLUS: Weighted F1 = 0.3993
#   Test on Politifact: Weighted F1 = 0.5040
#   Test on Unipi_NDF: Weighted F1 = 0.4654
#
# Results after training on LIAR_PLUS:
#   Test on Celebrity: Weighted F1 = 0.5100
#   Test on CIDII: Weighted F1 = 0.4435
#   Test on FaKES: Weighted F1 = 0.5418
#   Test on FakeVsSatire: Weighted F1 = 0.6027
#   Test on Horne: Weighted F1 = 0.5522
#   Test on Infodemic: Weighted F1 = 0.5819
#   Test on ISOT: Weighted F1 = 0.5630
#   Test on Kaggle_clement: Weighted F1 = 0.5736
#   Test on Kaggle_meg: Weighted F1 = 0.7298
#   Test on LIAR_PLUS: Weighted F1 = 0.5896
#   Test on Politifact: Weighted F1 = 0.6786
#   Test on Unipi_NDF: Weighted F1 = 0.4572
#
# Results after training on Politifact:
#   Test on Celebrity: Weighted F1 = 0.3628
#   Test on CIDII: Weighted F1 = 0.4333
#   Test on FaKES: Weighted F1 = 0.3606
#   Test on FakeVsSatire: Weighted F1 = 0.3878
#   Test on Horne: Weighted F1 = 0.5806
#   Test on Infodemic: Weighted F1 = 0.4337
#   Test on ISOT: Weighted F1 = 0.5055
#   Test on Kaggle_clement: Weighted F1 = 0.5655
#   Test on Kaggle_meg: Weighted F1 = 0.9265
#   Test on LIAR_PLUS: Weighted F1 = 0.4120
#   Test on Politifact: Weighted F1 = 0.7412
#   Test on Unipi_NDF: Weighted F1 = 0.4849
#
# Results after training on Unipi_NDF:
#   Test on Celebrity: Weighted F1 = 0.5536
#   Test on CIDII: Weighted F1 = 0.3603
#   Test on FaKES: Weighted F1 = 0.3333
#   Test on FakeVsSatire: Weighted F1 = 0.5175
#   Test on Horne: Weighted F1 = 0.3891
#   Test on Infodemic: Weighted F1 = 0.5859
#   Test on ISOT: Weighted F1 = 0.4038
#   Test on Kaggle_clement: Weighted F1 = 0.3864
#   Test on Kaggle_meg: Weighted F1 = 0.5329
#   Test on LIAR_PLUS: Weighted F1 = 0.5102
#   Test on Politifact: Weighted F1 = 0.5247
#   Test on Unipi_NDF: Weighted F1 = 0.8107

# %% [markdown]
# ## VERSION 2: Dataset by Topic

# %%
# -------------------------------
# Fine-tuning on Dataset by Topic
# -------------------------------

dataset_df = data_by_topic()

datasets = {topic: split_dataset(df) for topic, df in dataset_df.items()} # split all datasets in train/val/test
model = build_model() # initialize model

results = {}

# sequential training
for i, (topic, data) in enumerate(datasets.items()):
    print(f"\n=== Phase {i+1}: Training/Fine-tuning on topic: {topic} ===")
    
    X_train, y_train = data["train"]
    X_val, y_val = data["val"]
    X_test, y_test = data["test"]

    model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val])) # fine-tune on train + val

    y_pred = model.predict(X_test)
    print(f"Classification Report after topic {topic}:")
    print(classification_report(y_test, y_pred))
    print(f"Confusion Matrix after topic {topic}:")
    print(confusion_matrix(y_test, y_pred))
    print(f"\nWeighted F1-score after topic {topic}:", f1_score(y_test, y_pred, average="weighted"))


    # evaluation on all topics
    print("\n--- Evaluation on all topics ---")
    results[topic] = {}
    for test_topic, test_data in datasets.items(): # for each topic
        X_te, y_te = test_data["test"]
        preds = model.predict(X_te)
        f1 = f1_score(y_te, preds, average="weighted")
        results[topic][test_topic] = f1
        print(f"Evaluation on topic {test_topic}: Weighted F1 = {f1:.4f}")
# Out:
# /home/n.emmolo/progetto_tesi/src/utils.py:162: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   dfKaggleMeg['date'] = pd.to_datetime(dfKaggleMeg['date'], errors='coerce') # convert date column to datetime, coerce errors to NaT
# === Phase 1: Training/Fine-tuning on topic: politics ===
# Classification Report after topic politics:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.93     10094
#          1.0       0.93      0.93      0.93      9402
#
#     accuracy                           0.93     19496
#    macro avg       0.93      0.93      0.93     19496
# weighted avg       0.93      0.93      0.93     19496
#
# Confusion Matrix after topic politics:
# [[9416  678]
#  [ 643 8759]]
#
# Weighted F1-score after topic politics: 0.9322466151502965
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.9322
# Evaluation on topic general: Weighted F1 = 0.2212
# Evaluation on topic covid: Weighted F1 = 0.3626
# Evaluation on topic syria: Weighted F1 = 0.4746
# Evaluation on topic islam: Weighted F1 = 0.4866
# Evaluation on topic notredame: Weighted F1 = 0.2855
# Evaluation on topic gossip: Weighted F1 = 0.3711
#
# === Phase 2: Training/Fine-tuning on topic: general ===
# Classification Report after topic general:
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      2514
#          1.0       1.00      0.02      0.04        55
#
#     accuracy                           0.98      2569
#    macro avg       0.99      0.51      0.51      2569
# weighted avg       0.98      0.98      0.97      2569
#
# Confusion Matrix after topic general:
# [[2514    0]
#  [  54    1]]
#
# Weighted F1-score after topic general: 0.9689572520971367
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.3532
# Evaluation on topic general: Weighted F1 = 0.9690
# Evaluation on topic covid: Weighted F1 = 0.3600
# Evaluation on topic syria: Weighted F1 = 0.3633
# Evaluation on topic islam: Weighted F1 = 0.4333
# Evaluation on topic notredame: Weighted F1 = 0.4654
# Evaluation on topic gossip: Weighted F1 = 0.3333
#
# === Phase 3: Training/Fine-tuning on topic: covid ===
# Classification Report after topic covid:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94      1106
#          1.0       0.94      0.94      0.94      1006
#
#     accuracy                           0.94      2112
#    macro avg       0.94      0.94      0.94      2112
# weighted avg       0.94      0.94      0.94      2112
#
# Confusion Matrix after topic covid:
# [[1041   65]
#  [  62  944]]
#
# Weighted F1-score after topic covid: 0.939871355504798
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.3696
# Evaluation on topic general: Weighted F1 = 0.1997
# Evaluation on topic covid: Weighted F1 = 0.9399
# Evaluation on topic syria: Weighted F1 = 0.3363
# Evaluation on topic islam: Weighted F1 = 0.2892
# Evaluation on topic notredame: Weighted F1 = 0.4123
# Evaluation on topic gossip: Weighted F1 = 0.3929
#
# === Phase 4: Training/Fine-tuning on topic: syria ===
# Classification Report after topic syria:
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.76      0.65        89
#          1.0       0.56      0.34      0.42        80
#
#     accuracy                           0.56       169
#    macro avg       0.56      0.55      0.53       169
# weighted avg       0.56      0.56      0.54       169
#
# Confusion Matrix after topic syria:
# [[68 21]
#  [53 27]]
#
# Weighted F1-score after topic syria: 0.5407579599887292
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.3920
# Evaluation on topic general: Weighted F1 = 0.8929
# Evaluation on topic covid: Weighted F1 = 0.4614
# Evaluation on topic syria: Weighted F1 = 0.5408
# Evaluation on topic islam: Weighted F1 = 0.4977
# Evaluation on topic notredame: Weighted F1 = 0.4558
# Evaluation on topic gossip: Weighted F1 = 0.3686
#
# === Phase 5: Training/Fine-tuning on topic: islam ===
# Classification Report after topic islam:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.98      0.90        85
#          1.0       0.96      0.73      0.83        60
#
#     accuracy                           0.88       145
#    macro avg       0.90      0.85      0.87       145
# weighted avg       0.89      0.88      0.87       145
#
# Confusion Matrix after topic islam:
# [[83  2]
#  [16 44]]
#
# Weighted F1-score after topic islam: 0.8723869197476734
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.4739
# Evaluation on topic general: Weighted F1 = 0.9043
# Evaluation on topic covid: Weighted F1 = 0.4860
# Evaluation on topic syria: Weighted F1 = 0.3764
# Evaluation on topic islam: Weighted F1 = 0.8724
# Evaluation on topic notredame: Weighted F1 = 0.6775
# Evaluation on topic gossip: Weighted F1 = 0.4415
#
# === Phase 6: Training/Fine-tuning on topic: notredame ===
# Classification Report after topic notredame:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.96      0.87        68
#          1.0       0.90      0.60      0.72        43
#
#     accuracy                           0.82       111
#    macro avg       0.84      0.78      0.79       111
# weighted avg       0.83      0.82      0.81       111
#
# Confusion Matrix after topic notredame:
# [[65  3]
#  [17 26]]
#
# Weighted F1-score after topic notredame: 0.8107107107107108
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.4327
# Evaluation on topic general: Weighted F1 = 0.5329
# Evaluation on topic covid: Weighted F1 = 0.5859
# Evaluation on topic syria: Weighted F1 = 0.3333
# Evaluation on topic islam: Weighted F1 = 0.3603
# Evaluation on topic notredame: Weighted F1 = 0.8107
# Evaluation on topic gossip: Weighted F1 = 0.5536
#
# === Phase 7: Training/Fine-tuning on topic: gossip ===
# Classification Report after topic gossip:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.84      0.73        50
#          1.0       0.77      0.54      0.64        50
#
#     accuracy                           0.69       100
#    macro avg       0.71      0.69      0.68       100
# weighted avg       0.71      0.69      0.68       100
#
# Confusion Matrix after topic gossip:
# [[42  8]
#  [23 27]]
#
# Weighted F1-score after topic gossip: 0.6828644501278772
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.4255
# Evaluation on topic general: Weighted F1 = 0.8955
# Evaluation on topic covid: Weighted F1 = 0.5466
# Evaluation on topic syria: Weighted F1 = 0.4241
# Evaluation on topic islam: Weighted F1 = 0.5762
# Evaluation on topic notredame: Weighted F1 = 0.5003
# Evaluation on topic gossip: Weighted F1 = 0.6829

# %%
# ---------------
# Results summary
# ---------------

print("\n=== Results Summary ===")
for topic, res in results.items():
    print(f"\nResults after training on topic {topic}:")
    for test_topic, f1 in res.items():
        print(f"  Test on topic {test_topic}: Weighted F1 = {f1:.4f}")
# Out:
# === Results Summary ===
#
# Results after training on topic politics:
#   Test on topic politics: Weighted F1 = 0.9322
#   Test on topic general: Weighted F1 = 0.2212
#   Test on topic covid: Weighted F1 = 0.3626
#   Test on topic syria: Weighted F1 = 0.4746
#   Test on topic islam: Weighted F1 = 0.4866
#   Test on topic notredame: Weighted F1 = 0.2855
#   Test on topic gossip: Weighted F1 = 0.3711
#
# Results after training on topic general:
#   Test on topic politics: Weighted F1 = 0.3532
#   Test on topic general: Weighted F1 = 0.9690
#   Test on topic covid: Weighted F1 = 0.3600
#   Test on topic syria: Weighted F1 = 0.3633
#   Test on topic islam: Weighted F1 = 0.4333
#   Test on topic notredame: Weighted F1 = 0.4654
#   Test on topic gossip: Weighted F1 = 0.3333
#
# Results after training on topic covid:
#   Test on topic politics: Weighted F1 = 0.3696
#   Test on topic general: Weighted F1 = 0.1997
#   Test on topic covid: Weighted F1 = 0.9399
#   Test on topic syria: Weighted F1 = 0.3363
#   Test on topic islam: Weighted F1 = 0.2892
#   Test on topic notredame: Weighted F1 = 0.4123
#   Test on topic gossip: Weighted F1 = 0.3929
#
# Results after training on topic syria:
#   Test on topic politics: Weighted F1 = 0.3920
#   Test on topic general: Weighted F1 = 0.8929
#   Test on topic covid: Weighted F1 = 0.4614
#   Test on topic syria: Weighted F1 = 0.5408
#   Test on topic islam: Weighted F1 = 0.4977
#   Test on topic notredame: Weighted F1 = 0.4558
#   Test on topic gossip: Weighted F1 = 0.3686
#
# Results after training on topic islam:
#   Test on topic politics: Weighted F1 = 0.4739
#   Test on topic general: Weighted F1 = 0.9043
#   Test on topic covid: Weighted F1 = 0.4860
#   Test on topic syria: Weighted F1 = 0.3764
#   Test on topic islam: Weighted F1 = 0.8724
#   Test on topic notredame: Weighted F1 = 0.6775
#   Test on topic gossip: Weighted F1 = 0.4415
#
# Results after training on topic notredame:
#   Test on topic politics: Weighted F1 = 0.4327
#   Test on topic general: Weighted F1 = 0.5329
#   Test on topic covid: Weighted F1 = 0.5859
#   Test on topic syria: Weighted F1 = 0.3333
#   Test on topic islam: Weighted F1 = 0.3603
#   Test on topic notredame: Weighted F1 = 0.8107
#   Test on topic gossip: Weighted F1 = 0.5536
#
# Results after training on topic gossip:
#   Test on topic politics: Weighted F1 = 0.4255
#   Test on topic general: Weighted F1 = 0.8955
#   Test on topic covid: Weighted F1 = 0.5466
#   Test on topic syria: Weighted F1 = 0.4241
#   Test on topic islam: Weighted F1 = 0.5762
#   Test on topic notredame: Weighted F1 = 0.5003
#   Test on topic gossip: Weighted F1 = 0.6829

# %% [markdown]
# ## VERSION 3: Dataset by Date

# %%
dataset_df = data_by_date()

for date, df in dataset_df.items():
    print(f"Date: {date}, Number of samples: {len(df)}")
# Out:
# /home/n.emmolo/progetto_tesi/src/utils.py:162: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   dfKaggleMeg['date'] = pd.to_datetime(dfKaggleMeg['date'], errors='coerce') # convert date column to datetime, coerce errors to NaT
# {'2011-2013': 55, 2014: 114, 2015: 84, 2016: 49687, 2017: 16657, 2020: 10559}

# %%
# ------------------------------
# Fine-tuning on Dataset by Date
# ------------------------------

dataset_df = data_by_date()

datasets = {date: split_dataset(df) for date, df in dataset_df.items()} # split all datasets in train/val/test
model = build_model() # initialize model

results = {}

# sequential training
for i, (date, data) in enumerate(datasets.items()):
    print(f"\n=== Phase {i+1}: Training/Fine-tuning on date: {date} ===")
    
    X_train, y_train = data["train"]
    X_val, y_val = data["val"]
    X_test, y_test = data["test"]

    model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val])) # fine-tune on train + val

    y_pred = model.predict(X_test)
    print(f"Classification Report after date {date}:")
    print(classification_report(y_test, y_pred))
    print(f"Confusion Matrix after date {date}:")
    print(confusion_matrix(y_test, y_pred))
    print(f"\nWeighted F1-score after date {date}:", f1_score(y_test, y_pred, average="weighted"))


    # evaluation on all dates
    print("\n--- Evaluation on all dates ---")
    results[date] = {}
    for test_date, test_data in datasets.items(): # for each date
        X_te, y_te = test_data["test"]
        preds = model.predict(X_te)
        f1 = f1_score(y_te, preds, average="weighted")
        results[date][test_date] = f1
        print(f"Evaluation on date {test_date}: Weighted F1 = {f1:.4f}")
# Out:
# /home/n.emmolo/progetto_tesi/src/utils.py:162: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   dfKaggleMeg['date'] = pd.to_datetime(dfKaggleMeg['date'], errors='coerce') # convert date column to datetime, coerce errors to NaT
# === Phase 1: Training/Fine-tuning on date: 2011-2013 ===
# Classification Report after date 2011-2013:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.20      0.33         5
#          1.0       0.60      1.00      0.75         6
#
#     accuracy                           0.64        11
#    macro avg       0.80      0.60      0.54        11
# weighted avg       0.78      0.64      0.56        11
#
# Confusion Matrix after date 2011-2013:
# [[1 4]
#  [0 6]]
#
# Weighted F1-score after date 2011-2013: 0.5606060606060606
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.5606
# Evaluation on date 2014: Weighted F1 = 0.2690
# Evaluation on date 2015: Weighted F1 = 0.3665
# Evaluation on date 2016: Weighted F1 = 0.3004
# Evaluation on date 2017: Weighted F1 = 0.0030
# Evaluation on date 2020: Weighted F1 = 0.3070
#
# === Phase 2: Training/Fine-tuning on date: 2014 ===
# Classification Report after date 2014:
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.33      0.38        12
#          1.0       0.43      0.55      0.48        11
#
#     accuracy                           0.43        23
#    macro avg       0.44      0.44      0.43        23
# weighted avg       0.44      0.43      0.43        23
#
# Confusion Matrix after date 2014:
# [[4 8]
#  [5 6]]
#
# Weighted F1-score after date 2014: 0.4283229813664596
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.6303
# Evaluation on date 2014: Weighted F1 = 0.4283
# Evaluation on date 2015: Weighted F1 = 0.4938
# Evaluation on date 2016: Weighted F1 = 0.3604
# Evaluation on date 2017: Weighted F1 = 0.8698
# Evaluation on date 2020: Weighted F1 = 0.3937
#
# === Phase 3: Training/Fine-tuning on date: 2015 ===
# Classification Report after date 2015:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         8
#          1.0       0.53      1.00      0.69         9
#
#     accuracy                           0.53        17
#    macro avg       0.26      0.50      0.35        17
# weighted avg       0.28      0.53      0.37        17
#
# Confusion Matrix after date 2015:
# [[0 8]
#  [0 9]]
#
# Weighted F1-score after date 2015: 0.36651583710407243
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.3409
# Evaluation on date 2014: Weighted F1 = 0.3095
# Evaluation on date 2015: Weighted F1 = 0.3665
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Evaluation on date 2016: Weighted F1 = 0.3174
# Evaluation on date 2017: Weighted F1 = 0.0667
# Evaluation on date 2020: Weighted F1 = 0.3219
#
# === Phase 4: Training/Fine-tuning on date: 2016 ===
# Classification Report after date 2016:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      5306
#          1.0       0.98      0.98      0.98      4632
#
#     accuracy                           0.98      9938
#    macro avg       0.98      0.98      0.98      9938
# weighted avg       0.98      0.98      0.98      9938
#
# Confusion Matrix after date 2016:
# [[5232   74]
#  [  80 4552]]
#
# Weighted F1-score after date 2016: 0.9845032811664566
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.3961
# Evaluation on date 2014: Weighted F1 = 0.4214
# Evaluation on date 2015: Weighted F1 = 0.3827
# Evaluation on date 2016: Weighted F1 = 0.9845
# Evaluation on date 2017: Weighted F1 = 0.9915
# Evaluation on date 2020: Weighted F1 = 0.3092
#
# === Phase 5: Training/Fine-tuning on date: 2017 ===
# Classification Report after date 2017:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      3318
#          1.0       0.00      0.00      0.00        14
#
#     accuracy                           1.00      3332
#    macro avg       0.50      0.50      0.50      3332
# weighted avg       0.99      1.00      0.99      3332
#
# Confusion Matrix after date 2017:
# [[3318    0]
#  [  14    0]]
#
# Weighted F1-score after date 2017: 0.9937019018133569
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.2841
# Evaluation on date 2014: Weighted F1 = 0.3578
# Evaluation on date 2015: Weighted F1 = 0.3012
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Evaluation on date 2016: Weighted F1 = 0.3719
# Evaluation on date 2017: Weighted F1 = 0.9937
# Evaluation on date 2020: Weighted F1 = 0.3600
#
# === Phase 6: Training/Fine-tuning on date: 2020 ===
# Classification Report after date 2020:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.93      1106
#          1.0       0.92      0.93      0.93      1006
#
#     accuracy                           0.93      2112
#    macro avg       0.93      0.93      0.93      2112
# weighted avg       0.93      0.93      0.93      2112
#
# Confusion Matrix after date 2020:
# [[1026   80]
#  [  68  938]]
#
# Weighted F1-score after date 2020: 0.9299408611809796
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.3409
# Evaluation on date 2014: Weighted F1 = 0.3991
# Evaluation on date 2015: Weighted F1 = 0.3388
# Evaluation on date 2016: Weighted F1 = 0.3473
# Evaluation on date 2017: Weighted F1 = 0.1014
# Evaluation on date 2020: Weighted F1 = 0.9299

# %%
# ---------------
# Results summary
# ---------------

print("\n=== Results Summary ===")
for date, res in results.items():
    print(f"\nResults after training on date {date}:")
    for test_date, f1 in res.items():
        print(f"  Test on date {test_date}: Weighted F1 = {f1:.4f}")
# Out:
# === Results Summary ===
#
# Results after training on date 2011-2013:
#   Test on date 2011-2013: Weighted F1 = 0.5606
#   Test on date 2014: Weighted F1 = 0.2690
#   Test on date 2015: Weighted F1 = 0.3665
#   Test on date 2016: Weighted F1 = 0.3004
#   Test on date 2017: Weighted F1 = 0.0030
#   Test on date 2020: Weighted F1 = 0.3070
#
# Results after training on date 2014:
#   Test on date 2011-2013: Weighted F1 = 0.6303
#   Test on date 2014: Weighted F1 = 0.4283
#   Test on date 2015: Weighted F1 = 0.4938
#   Test on date 2016: Weighted F1 = 0.3604
#   Test on date 2017: Weighted F1 = 0.8698
#   Test on date 2020: Weighted F1 = 0.3937
#
# Results after training on date 2015:
#   Test on date 2011-2013: Weighted F1 = 0.3409
#   Test on date 2014: Weighted F1 = 0.3095
#   Test on date 2015: Weighted F1 = 0.3665
#   Test on date 2016: Weighted F1 = 0.3174
#   Test on date 2017: Weighted F1 = 0.0667
#   Test on date 2020: Weighted F1 = 0.3219
#
# Results after training on date 2016:
#   Test on date 2011-2013: Weighted F1 = 0.3961
#   Test on date 2014: Weighted F1 = 0.4214
#   Test on date 2015: Weighted F1 = 0.3827
#   Test on date 2016: Weighted F1 = 0.9845
#   Test on date 2017: Weighted F1 = 0.9915
#   Test on date 2020: Weighted F1 = 0.3092
#
# Results after training on date 2017:
#   Test on date 2011-2013: Weighted F1 = 0.2841
#   Test on date 2014: Weighted F1 = 0.3578
#   Test on date 2015: Weighted F1 = 0.3012
#   Test on date 2016: Weighted F1 = 0.3719
#   Test on date 2017: Weighted F1 = 0.9937
#   Test on date 2020: Weighted F1 = 0.3600
#
# Results after training on date 2020:
#   Test on date 2011-2013: Weighted F1 = 0.3409
#   Test on date 2014: Weighted F1 = 0.3991
#   Test on date 2015: Weighted F1 = 0.3388
#   Test on date 2016: Weighted F1 = 0.3473
#   Test on date 2017: Weighted F1 = 0.1014
#   Test on date 2020: Weighted F1 = 0.9299
