# %% [markdown]
# # **SUPPORT VECTOR MACHINE**

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1" # "0" o "1"

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
from utils import *

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, f1_score, confusion_matrix

# %%
# -----------------------
# Model building function
# -----------------------

def build_model(C=10.0, penalty="l1", loss="squared_hinge", dual=False):
    """
    Builds a scikit-learn Pipeline with TF-IDF vectorization and SVM classifier.

    Args:
        C (float): Inverse of regularization strength for SVM.
        penalty (str): Regularization type for SVM.
        loss (str): Loss function to use for SVM.
        dual (bool): Whether to solve the dual optimization problem.

    Returns:
        Pipeline: A scikit-learn Pipeline object (TF-IDF + SVM).
    """
    
    return Pipeline([
        ('tfidf', TfidfVectorizer(  # TD-IDF vectorization inside pipeline
            max_features=5000,      # limit to top 5000 features
            ngram_range=(1, 2),     # unigrams + bigrams
            stop_words="english"    # remove English stop words
        )),
        ('clf', LinearSVC(         # Linear SVM classifier
            C=C,
            penalty=penalty,
            loss=loss,
            dual=dual,
            max_iter=2000,
            random_state=42
        ))
    ])

# %% [markdown]
# ## VERSION 1: Dataset (Simple)

# %%
# --------------------------------
# Fine-tuning on multiple datasets
# --------------------------------

datasets_df = data_loading() # load datasets

datasets = {name: split_dataset(df) for name, df in datasets_df.items()} # split all datasets in train/val/test
model = build_model() # initialize model

results = {}

# sequential training
for i, (name, data) in enumerate(datasets.items()):
    print(f"\n=== Phase {i+1}: Training/Fine-tuning on {name} ===")
    
    X_train, y_train = data["train"]
    X_val, y_val = data["val"]
    X_test, y_test = data["test"]

    model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val])) # fine-tune on train + val

    y_pred = model.predict(X_test)
    print(f"Classification Report after {name}:")
    print(classification_report(y_test, y_pred))
    print(f"Confusion Matrix after {name}:")
    print(confusion_matrix(y_test, y_pred))
    print(f"\nWeighted F1-score after {name}:", f1_score(y_test, y_pred, average="weighted"))


    # evaluation on all datasets
    print("\n--- Evaluation on all datasets ---")
    results[name] = {}
    for test_name, test_data in datasets.items(): # for each dataset
        X_te, y_te = test_data["test"]
        preds = model.predict(X_te)
        f1 = f1_score(y_te, preds, average="weighted")
        results[name][test_name] = f1
        print(f"Evaluation on {test_name}: Weighted F1 = {f1:.4f}")
# Out:
# /home/n.emmolo/progetto_tesi/src/utils.py:162: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   dfKaggleMeg['date'] = pd.to_datetime(dfKaggleMeg['date'], errors='coerce') # convert date column to datetime, coerce errors to NaT
# === Phase 1: Training/Fine-tuning on Celebrity ===
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Classification Report after Celebrity:
#               precision    recall  f1-score   support
#
#            0       0.58      0.68      0.62        50
#            1       0.61      0.50      0.55        50
#
#     accuracy                           0.59       100
#    macro avg       0.59      0.59      0.59       100
# weighted avg       0.59      0.59      0.59       100
#
# Confusion Matrix after Celebrity:
# [[34 16]
#  [25 25]]
#
# Weighted F1-score after Celebrity: 0.5866518802298619
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.5867
# Evaluation on CIDII: Weighted F1 = 0.5747
# Evaluation on FaKES: Weighted F1 = 0.4011
# Evaluation on FakeVsSatire: Weighted F1 = 0.4506
# Evaluation on Horne: Weighted F1 = 0.6382
# Evaluation on Infodemic: Weighted F1 = 0.4439
# Evaluation on ISOT: Weighted F1 = 0.4919
# Evaluation on Kaggle_clement: Weighted F1 = 0.5220
# Evaluation on Kaggle_meg: Weighted F1 = 0.8742
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4593
# Evaluation on Politifact: Weighted F1 = 0.5542
# Evaluation on Unipi_NDF: Weighted F1 = 0.4245
#
# === Phase 2: Training/Fine-tuning on CIDII ===
# Classification Report after CIDII:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.90        85
#            1       0.92      0.75      0.83        60
#
#     accuracy                           0.87       145
#    macro avg       0.88      0.85      0.86       145
# weighted avg       0.87      0.87      0.87       145
#
# Confusion Matrix after CIDII:
# [[81  4]
#  [15 45]]
#
# Weighted F1-score after CIDII: 0.8663353963446074
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3967
# Evaluation on CIDII: Weighted F1 = 0.8663
# Evaluation on FaKES: Weighted F1 = 0.3803
# Evaluation on FakeVsSatire: Weighted F1 = 0.4202
# Evaluation on Horne: Weighted F1 = 0.6812
# Evaluation on Infodemic: Weighted F1 = 0.4553
# Evaluation on ISOT: Weighted F1 = 0.4186
# Evaluation on Kaggle_clement: Weighted F1 = 0.4727
# Evaluation on Kaggle_meg: Weighted F1 = 0.9002
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4759
# Evaluation on Politifact: Weighted F1 = 0.5765
# Evaluation on Unipi_NDF: Weighted F1 = 0.6322
#
# === Phase 3: Training/Fine-tuning on FaKES ===
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Classification Report after FaKES:
#               precision    recall  f1-score   support
#
#            0       0.54      0.61      0.57        89
#            1       0.49      0.42      0.46        80
#
#     accuracy                           0.52       169
#    macro avg       0.52      0.52      0.51       169
# weighted avg       0.52      0.52      0.52       169
#
# Confusion Matrix after FaKES:
# [[54 35]
#  [46 34]]
#
# Weighted F1-score after FaKES: 0.516965739474774
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4987
# Evaluation on CIDII: Weighted F1 = 0.5146
# Evaluation on FaKES: Weighted F1 = 0.5170
# Evaluation on FakeVsSatire: Weighted F1 = 0.3765
# Evaluation on Horne: Weighted F1 = 0.5922
# Evaluation on Infodemic: Weighted F1 = 0.4655
# Evaluation on ISOT: Weighted F1 = 0.4428
# Evaluation on Kaggle_clement: Weighted F1 = 0.4627
# Evaluation on Kaggle_meg: Weighted F1 = 0.7731
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4932
# Evaluation on Politifact: Weighted F1 = 0.5034
# Evaluation on Unipi_NDF: Weighted F1 = 0.5759
#
# === Phase 4: Training/Fine-tuning on FakeVsSatire ===
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Classification Report after FakeVsSatire:
#               precision    recall  f1-score   support
#
#            0       0.77      0.66      0.71        41
#            1       0.78      0.86      0.82        57
#
#     accuracy                           0.78        98
#    macro avg       0.77      0.76      0.76        98
# weighted avg       0.78      0.78      0.77        98
#
# Confusion Matrix after FakeVsSatire:
# [[27 14]
#  [ 8 49]]
#
# Weighted F1-score after FakeVsSatire: 0.7722610096670247
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4858
# Evaluation on CIDII: Weighted F1 = 0.3953
# Evaluation on FaKES: Weighted F1 = 0.4445
# Evaluation on FakeVsSatire: Weighted F1 = 0.7723
# Evaluation on Horne: Weighted F1 = 0.5961
# Evaluation on Infodemic: Weighted F1 = 0.3526
# Evaluation on ISOT: Weighted F1 = 0.4438
# Evaluation on Kaggle_clement: Weighted F1 = 0.4097
# Evaluation on Kaggle_meg: Weighted F1 = 0.4682
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4095
# Evaluation on Politifact: Weighted F1 = 0.3843
# Evaluation on Unipi_NDF: Weighted F1 = 0.4605
#
# === Phase 5: Training/Fine-tuning on Horne ===
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Classification Report after Horne:
#               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85        41
#            1       0.80      0.64      0.71        25
#
#     accuracy                           0.80        66
#    macro avg       0.80      0.77      0.78        66
# weighted avg       0.80      0.80      0.80        66
#
# Confusion Matrix after Horne:
# [[37  4]
#  [ 9 16]]
#
# Weighted F1-score after Horne: 0.7977475908510391
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.5806
# Evaluation on CIDII: Weighted F1 = 0.6254
# Evaluation on FaKES: Weighted F1 = 0.4748
# Evaluation on FakeVsSatire: Weighted F1 = 0.6646
# Evaluation on Horne: Weighted F1 = 0.7977
# Evaluation on Infodemic: Weighted F1 = 0.4667
# Evaluation on ISOT: Weighted F1 = 0.5524
# Evaluation on Kaggle_clement: Weighted F1 = 0.5690
# Evaluation on Kaggle_meg: Weighted F1 = 0.6869
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4951
# Evaluation on Politifact: Weighted F1 = 0.6395
# Evaluation on Unipi_NDF: Weighted F1 = 0.4347
#
# === Phase 6: Training/Fine-tuning on Infodemic ===
# Classification Report after Infodemic:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.93      1106
#          1.0       0.92      0.94      0.93      1006
#
#     accuracy                           0.93      2112
#    macro avg       0.93      0.93      0.93      2112
# weighted avg       0.93      0.93      0.93      2112
#
# Confusion Matrix after Infodemic:
# [[1025   81]
#  [  64  942]]
#
# Weighted F1-score after Infodemic: 0.9313664482352475
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4650
# Evaluation on CIDII: Weighted F1 = 0.3886
# Evaluation on FaKES: Weighted F1 = 0.5101
# Evaluation on FakeVsSatire: Weighted F1 = 0.4566
# Evaluation on Horne: Weighted F1 = 0.3461
# Evaluation on Infodemic: Weighted F1 = 0.9314
# Evaluation on ISOT: Weighted F1 = 0.5061
# Evaluation on Kaggle_clement: Weighted F1 = 0.4638
# Evaluation on Kaggle_meg: Weighted F1 = 0.3855
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4297
# Evaluation on Politifact: Weighted F1 = 0.4920
# Evaluation on Unipi_NDF: Weighted F1 = 0.3419
#
# === Phase 7: Training/Fine-tuning on ISOT ===
# Classification Report after ISOT:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4284
#            1       1.00      1.00      1.00      4571
#
#     accuracy                           1.00      8855
#    macro avg       1.00      1.00      1.00      8855
# weighted avg       1.00      1.00      1.00      8855
#
# Confusion Matrix after ISOT:
# [[4278    6]
#  [  13 4558]]
#
# Weighted F1-score after ISOT: 0.9978543732815983
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3552
# Evaluation on CIDII: Weighted F1 = 0.3134
# Evaluation on FaKES: Weighted F1 = 0.5020
# Evaluation on FakeVsSatire: Weighted F1 = 0.6411
# Evaluation on Horne: Weighted F1 = 0.6865
# Evaluation on Infodemic: Weighted F1 = 0.3202
# Evaluation on ISOT: Weighted F1 = 0.9979
# Evaluation on Kaggle_clement: Weighted F1 = 0.9928
# Evaluation on Kaggle_meg: Weighted F1 = 0.0612
# Evaluation on LIAR_PLUS: Weighted F1 = 0.2950
# Evaluation on Politifact: Weighted F1 = 0.3387
# Evaluation on Unipi_NDF: Weighted F1 = 0.2724
#
# === Phase 8: Training/Fine-tuning on Kaggle_clement ===
# Classification Report after Kaggle_clement:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      4240
#            1       1.00      0.99      1.00      3581
#
#     accuracy                           1.00      7821
#    macro avg       1.00      1.00      1.00      7821
# weighted avg       1.00      1.00      1.00      7821
#
# Confusion Matrix after Kaggle_clement:
# [[4227   13]
#  [  22 3559]]
#
# Weighted F1-score after Kaggle_clement: 0.9955244258648097
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.3503
# Evaluation on CIDII: Weighted F1 = 0.4277
# Evaluation on FaKES: Weighted F1 = 0.5030
# Evaluation on FakeVsSatire: Weighted F1 = 0.4278
# Evaluation on Horne: Weighted F1 = 0.2706
# Evaluation on Infodemic: Weighted F1 = 0.3298
# Evaluation on ISOT: Weighted F1 = 0.9972
# Evaluation on Kaggle_clement: Weighted F1 = 0.9955
# Evaluation on Kaggle_meg: Weighted F1 = 0.0656
# Evaluation on LIAR_PLUS: Weighted F1 = 0.2969
# Evaluation on Politifact: Weighted F1 = 0.2676
# Evaluation on Unipi_NDF: Weighted F1 = 0.2355
#
# === Phase 9: Training/Fine-tuning on Kaggle_meg ===
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Classification Report after Kaggle_meg:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2514
#            1       0.17      0.15      0.16        55
#
#     accuracy                           0.97      2569
#    macro avg       0.58      0.57      0.57      2569
# weighted avg       0.96      0.97      0.97      2569
#
# Confusion Matrix after Kaggle_meg:
# [[2476   38]
#  [  47    8]]
#
# Weighted F1-score after Kaggle_meg: 0.9654685906366277
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4172
# Evaluation on CIDII: Weighted F1 = 0.4487
# Evaluation on FaKES: Weighted F1 = 0.3803
# Evaluation on FakeVsSatire: Weighted F1 = 0.2468
# Evaluation on Horne: Weighted F1 = 0.4761
# Evaluation on Infodemic: Weighted F1 = 0.3920
# Evaluation on ISOT: Weighted F1 = 0.3323
# Evaluation on Kaggle_clement: Weighted F1 = 0.3963
# Evaluation on Kaggle_meg: Weighted F1 = 0.9655
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4097
# Evaluation on Politifact: Weighted F1 = 0.5040
# Evaluation on Unipi_NDF: Weighted F1 = 0.4654
#
# === Phase 10: Training/Fine-tuning on LIAR_PLUS ===
# Classification Report after LIAR_PLUS:
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.55      0.57      1426
#          1.0       0.47      0.50      0.48      1131
#
#     accuracy                           0.53      2557
#    macro avg       0.53      0.53      0.53      2557
# weighted avg       0.53      0.53      0.53      2557
#
# Confusion Matrix after LIAR_PLUS:
# [[790 636]
#  [566 565]]
#
# Weighted F1-score after LIAR_PLUS: 0.5310590905410607
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.5192
# Evaluation on CIDII: Weighted F1 = 0.5522
# Evaluation on FaKES: Weighted F1 = 0.4830
# Evaluation on FakeVsSatire: Weighted F1 = 0.5238
# Evaluation on Horne: Weighted F1 = 0.3867
# Evaluation on Infodemic: Weighted F1 = 0.5528
# Evaluation on ISOT: Weighted F1 = 0.5677
# Evaluation on Kaggle_clement: Weighted F1 = 0.5697
# Evaluation on Kaggle_meg: Weighted F1 = 0.6071
# Evaluation on LIAR_PLUS: Weighted F1 = 0.5311
# Evaluation on Politifact: Weighted F1 = 0.5927
# Evaluation on Unipi_NDF: Weighted F1 = 0.4453
#
# === Phase 11: Training/Fine-tuning on Politifact ===
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Classification Report after Politifact:
#               precision    recall  f1-score   support
#
#            0       0.79      0.95      0.87        65
#            1       0.87      0.56      0.68        36
#
#     accuracy                           0.81       101
#    macro avg       0.83      0.75      0.77       101
# weighted avg       0.82      0.81      0.80       101
#
# Confusion Matrix after Politifact:
# [[62  3]
#  [16 20]]
#
# Weighted F1-score after Politifact: 0.7997070893530032
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4179
# Evaluation on CIDII: Weighted F1 = 0.5136
# Evaluation on FaKES: Weighted F1 = 0.4573
# Evaluation on FakeVsSatire: Weighted F1 = 0.4824
# Evaluation on Horne: Weighted F1 = 0.6848
# Evaluation on Infodemic: Weighted F1 = 0.5102
# Evaluation on ISOT: Weighted F1 = 0.5614
# Evaluation on Kaggle_clement: Weighted F1 = 0.5794
# Evaluation on Kaggle_meg: Weighted F1 = 0.8264
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4452
# Evaluation on Politifact: Weighted F1 = 0.7997
# Evaluation on Unipi_NDF: Weighted F1 = 0.6028
#
# === Phase 12: Training/Fine-tuning on Unipi_NDF ===
# Classification Report after Unipi_NDF:
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87        68
#            1       0.83      0.70      0.76        43
#
#     accuracy                           0.83       111
#    macro avg       0.83      0.80      0.81       111
# weighted avg       0.83      0.83      0.83       111
#
# Confusion Matrix after Unipi_NDF:
# [[62  6]
#  [13 30]]
#
# Weighted F1-score after Unipi_NDF: 0.8254348001183444
#
# --- Evaluation on all datasets ---
# Evaluation on Celebrity: Weighted F1 = 0.4695
# Evaluation on CIDII: Weighted F1 = 0.3882
# Evaluation on FaKES: Weighted F1 = 0.4010
# Evaluation on FakeVsSatire: Weighted F1 = 0.4924
# Evaluation on Horne: Weighted F1 = 0.5152
# Evaluation on Infodemic: Weighted F1 = 0.5681
# Evaluation on ISOT: Weighted F1 = 0.5423
# Evaluation on Kaggle_clement: Weighted F1 = 0.5268
# Evaluation on Kaggle_meg: Weighted F1 = 0.5555
# Evaluation on LIAR_PLUS: Weighted F1 = 0.4557
# Evaluation on Politifact: Weighted F1 = 0.5913
# Evaluation on Unipi_NDF: Weighted F1 = 0.8254

# %%
# ---------------
# Results summary
# ---------------

print("\n=== Results Summary ===")
for name, res in results.items():
    print(f"\nResults after training on {name}:")
    for test_name, f1 in res.items():
        print(f"  Test on {test_name}: Weighted F1 = {f1:.4f}")
# Out:
# === Results Summary ===
#
# Results after training on Celebrity:
#   Test on Celebrity: Weighted F1 = 0.5867
#   Test on CIDII: Weighted F1 = 0.5747
#   Test on FaKES: Weighted F1 = 0.4011
#   Test on FakeVsSatire: Weighted F1 = 0.4506
#   Test on Horne: Weighted F1 = 0.6382
#   Test on Infodemic: Weighted F1 = 0.4439
#   Test on ISOT: Weighted F1 = 0.4919
#   Test on Kaggle_clement: Weighted F1 = 0.5220
#   Test on Kaggle_meg: Weighted F1 = 0.8742
#   Test on LIAR_PLUS: Weighted F1 = 0.4593
#   Test on Politifact: Weighted F1 = 0.5542
#   Test on Unipi_NDF: Weighted F1 = 0.4245
#
# Results after training on CIDII:
#   Test on Celebrity: Weighted F1 = 0.3967
#   Test on CIDII: Weighted F1 = 0.8663
#   Test on FaKES: Weighted F1 = 0.3803
#   Test on FakeVsSatire: Weighted F1 = 0.4202
#   Test on Horne: Weighted F1 = 0.6812
#   Test on Infodemic: Weighted F1 = 0.4553
#   Test on ISOT: Weighted F1 = 0.4186
#   Test on Kaggle_clement: Weighted F1 = 0.4727
#   Test on Kaggle_meg: Weighted F1 = 0.9002
#   Test on LIAR_PLUS: Weighted F1 = 0.4759
#   Test on Politifact: Weighted F1 = 0.5765
#   Test on Unipi_NDF: Weighted F1 = 0.6322
#
# Results after training on FaKES:
#   Test on Celebrity: Weighted F1 = 0.4987
#   Test on CIDII: Weighted F1 = 0.5146
#   Test on FaKES: Weighted F1 = 0.5170
#   Test on FakeVsSatire: Weighted F1 = 0.3765
#   Test on Horne: Weighted F1 = 0.5922
#   Test on Infodemic: Weighted F1 = 0.4655
#   Test on ISOT: Weighted F1 = 0.4428
#   Test on Kaggle_clement: Weighted F1 = 0.4627
#   Test on Kaggle_meg: Weighted F1 = 0.7731
#   Test on LIAR_PLUS: Weighted F1 = 0.4932
#   Test on Politifact: Weighted F1 = 0.5034
#   Test on Unipi_NDF: Weighted F1 = 0.5759
#
# Results after training on FakeVsSatire:
#   Test on Celebrity: Weighted F1 = 0.4858
#   Test on CIDII: Weighted F1 = 0.3953
#   Test on FaKES: Weighted F1 = 0.4445
#   Test on FakeVsSatire: Weighted F1 = 0.7723
#   Test on Horne: Weighted F1 = 0.5961
#   Test on Infodemic: Weighted F1 = 0.3526
#   Test on ISOT: Weighted F1 = 0.4438
#   Test on Kaggle_clement: Weighted F1 = 0.4097
#   Test on Kaggle_meg: Weighted F1 = 0.4682
#   Test on LIAR_PLUS: Weighted F1 = 0.4095
#   Test on Politifact: Weighted F1 = 0.3843
#   Test on Unipi_NDF: Weighted F1 = 0.4605
#
# Results after training on Horne:
#   Test on Celebrity: Weighted F1 = 0.5806
#   Test on CIDII: Weighted F1 = 0.6254
#   Test on FaKES: Weighted F1 = 0.4748
#   Test on FakeVsSatire: Weighted F1 = 0.6646
#   Test on Horne: Weighted F1 = 0.7977
#   Test on Infodemic: Weighted F1 = 0.4667
#   Test on ISOT: Weighted F1 = 0.5524
#   Test on Kaggle_clement: Weighted F1 = 0.5690
#   Test on Kaggle_meg: Weighted F1 = 0.6869
#   Test on LIAR_PLUS: Weighted F1 = 0.4951
#   Test on Politifact: Weighted F1 = 0.6395
#   Test on Unipi_NDF: Weighted F1 = 0.4347
#
# Results after training on Infodemic:
#   Test on Celebrity: Weighted F1 = 0.4650
#   Test on CIDII: Weighted F1 = 0.3886
#   Test on FaKES: Weighted F1 = 0.5101
#   Test on FakeVsSatire: Weighted F1 = 0.4566
#   Test on Horne: Weighted F1 = 0.3461
#   Test on Infodemic: Weighted F1 = 0.9314
#   Test on ISOT: Weighted F1 = 0.5061
#   Test on Kaggle_clement: Weighted F1 = 0.4638
#   Test on Kaggle_meg: Weighted F1 = 0.3855
#   Test on LIAR_PLUS: Weighted F1 = 0.4297
#   Test on Politifact: Weighted F1 = 0.4920
#   Test on Unipi_NDF: Weighted F1 = 0.3419
#
# Results after training on ISOT:
#   Test on Celebrity: Weighted F1 = 0.3552
#   Test on CIDII: Weighted F1 = 0.3134
#   Test on FaKES: Weighted F1 = 0.5020
#   Test on FakeVsSatire: Weighted F1 = 0.6411
#   Test on Horne: Weighted F1 = 0.6865
#   Test on Infodemic: Weighted F1 = 0.3202
#   Test on ISOT: Weighted F1 = 0.9979
#   Test on Kaggle_clement: Weighted F1 = 0.9928
#   Test on Kaggle_meg: Weighted F1 = 0.0612
#   Test on LIAR_PLUS: Weighted F1 = 0.2950
#   Test on Politifact: Weighted F1 = 0.3387
#   Test on Unipi_NDF: Weighted F1 = 0.2724
#
# Results after training on Kaggle_clement:
#   Test on Celebrity: Weighted F1 = 0.3503
#   Test on CIDII: Weighted F1 = 0.4277
#   Test on FaKES: Weighted F1 = 0.5030
#   Test on FakeVsSatire: Weighted F1 = 0.4278
#   Test on Horne: Weighted F1 = 0.2706
#   Test on Infodemic: Weighted F1 = 0.3298
#   Test on ISOT: Weighted F1 = 0.9972
#   Test on Kaggle_clement: Weighted F1 = 0.9955
#   Test on Kaggle_meg: Weighted F1 = 0.0656
#   Test on LIAR_PLUS: Weighted F1 = 0.2969
#   Test on Politifact: Weighted F1 = 0.2676
#   Test on Unipi_NDF: Weighted F1 = 0.2355
#
# Results after training on Kaggle_meg:
#   Test on Celebrity: Weighted F1 = 0.4172
#   Test on CIDII: Weighted F1 = 0.4487
#   Test on FaKES: Weighted F1 = 0.3803
#   Test on FakeVsSatire: Weighted F1 = 0.2468
#   Test on Horne: Weighted F1 = 0.4761
#   Test on Infodemic: Weighted F1 = 0.3920
#   Test on ISOT: Weighted F1 = 0.3323
#   Test on Kaggle_clement: Weighted F1 = 0.3963
#   Test on Kaggle_meg: Weighted F1 = 0.9655
#   Test on LIAR_PLUS: Weighted F1 = 0.4097
#   Test on Politifact: Weighted F1 = 0.5040
#   Test on Unipi_NDF: Weighted F1 = 0.4654
#
# Results after training on LIAR_PLUS:
#   Test on Celebrity: Weighted F1 = 0.5192
#   Test on CIDII: Weighted F1 = 0.5522
#   Test on FaKES: Weighted F1 = 0.4830
#   Test on FakeVsSatire: Weighted F1 = 0.5238
#   Test on Horne: Weighted F1 = 0.3867
#   Test on Infodemic: Weighted F1 = 0.5528
#   Test on ISOT: Weighted F1 = 0.5677
#   Test on Kaggle_clement: Weighted F1 = 0.5697
#   Test on Kaggle_meg: Weighted F1 = 0.6071
#   Test on LIAR_PLUS: Weighted F1 = 0.5311
#   Test on Politifact: Weighted F1 = 0.5927
#   Test on Unipi_NDF: Weighted F1 = 0.4453
#
# Results after training on Politifact:
#   Test on Celebrity: Weighted F1 = 0.4179
#   Test on CIDII: Weighted F1 = 0.5136
#   Test on FaKES: Weighted F1 = 0.4573
#   Test on FakeVsSatire: Weighted F1 = 0.4824
#   Test on Horne: Weighted F1 = 0.6848
#   Test on Infodemic: Weighted F1 = 0.5102
#   Test on ISOT: Weighted F1 = 0.5614
#   Test on Kaggle_clement: Weighted F1 = 0.5794
#   Test on Kaggle_meg: Weighted F1 = 0.8264
#   Test on LIAR_PLUS: Weighted F1 = 0.4452
#   Test on Politifact: Weighted F1 = 0.7997
#   Test on Unipi_NDF: Weighted F1 = 0.6028
#
# Results after training on Unipi_NDF:
#   Test on Celebrity: Weighted F1 = 0.4695
#   Test on CIDII: Weighted F1 = 0.3882
#   Test on FaKES: Weighted F1 = 0.4010
#   Test on FakeVsSatire: Weighted F1 = 0.4924
#   Test on Horne: Weighted F1 = 0.5152
#   Test on Infodemic: Weighted F1 = 0.5681
#   Test on ISOT: Weighted F1 = 0.5423
#   Test on Kaggle_clement: Weighted F1 = 0.5268
#   Test on Kaggle_meg: Weighted F1 = 0.5555
#   Test on LIAR_PLUS: Weighted F1 = 0.4557
#   Test on Politifact: Weighted F1 = 0.5913
#   Test on Unipi_NDF: Weighted F1 = 0.8254

# %% [markdown]
# ## VERSION 2: Dataset by Topic

# %%
# -------------------------------
# Fine-tuning on Dataset by Topic
# -------------------------------

dataset_df = data_by_topic()

datasets = {topic: split_dataset(df) for topic, df in dataset_df.items()} # split all datasets in train/val/test
model = build_model() # initialize model

results = {}

# sequential training
for i, (topic, data) in enumerate(datasets.items()):
    print(f"\n=== Phase {i+1}: Training/Fine-tuning on topic: {topic} ===")
    
    X_train, y_train = data["train"]
    X_val, y_val = data["val"]
    X_test, y_test = data["test"]

    model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val])) # fine-tune on train + val

    y_pred = model.predict(X_test)
    print(f"Classification Report after topic {topic}:")
    print(classification_report(y_test, y_pred))
    print(f"Confusion Matrix after topic {topic}:")
    print(confusion_matrix(y_test, y_pred))
    print(f"\nWeighted F1-score after topic {topic}:", f1_score(y_test, y_pred, average="weighted"))


    # evaluation on all topics
    print("\n--- Evaluation on all topics ---")
    results[topic] = {}
    for test_topic, test_data in datasets.items(): # for each topic
        X_te, y_te = test_data["test"]
        preds = model.predict(X_te)
        f1 = f1_score(y_te, preds, average="weighted")
        results[topic][test_topic] = f1
        print(f"Evaluation on topic {test_topic}: Weighted F1 = {f1:.4f}")
# Out:
# /home/n.emmolo/progetto_tesi/src/utils.py:162: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   dfKaggleMeg['date'] = pd.to_datetime(dfKaggleMeg['date'], errors='coerce') # convert date column to datetime, coerce errors to NaT
# === Phase 1: Training/Fine-tuning on topic: politics ===
# Classification Report after topic politics:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94     10094
#          1.0       0.93      0.93      0.93      9402
#
#     accuracy                           0.93     19496
#    macro avg       0.93      0.93      0.93     19496
# weighted avg       0.93      0.93      0.93     19496
#
# Confusion Matrix after topic politics:
# [[9476  618]
#  [ 657 8745]]
#
# Weighted F1-score after topic politics: 0.934597057541472
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.9346
# Evaluation on topic general: Weighted F1 = 0.3693
# Evaluation on topic covid: Weighted F1 = 0.3599
# Evaluation on topic syria: Weighted F1 = 0.5463
# Evaluation on topic islam: Weighted F1 = 0.4834
# Evaluation on topic notredame: Weighted F1 = 0.4718
# Evaluation on topic gossip: Weighted F1 = 0.3743
#
# === Phase 2: Training/Fine-tuning on topic: general ===
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Classification Report after topic general:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98      2514
#          1.0       0.17      0.15      0.16        55
#
#     accuracy                           0.97      2569
#    macro avg       0.58      0.57      0.57      2569
# weighted avg       0.96      0.97      0.97      2569
#
# Confusion Matrix after topic general:
# [[2476   38]
#  [  47    8]]
#
# Weighted F1-score after topic general: 0.9654685906366277
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.3690
# Evaluation on topic general: Weighted F1 = 0.9655
# Evaluation on topic covid: Weighted F1 = 0.3920
# Evaluation on topic syria: Weighted F1 = 0.3803
# Evaluation on topic islam: Weighted F1 = 0.4487
# Evaluation on topic notredame: Weighted F1 = 0.4654
# Evaluation on topic gossip: Weighted F1 = 0.4172
#
# === Phase 3: Training/Fine-tuning on topic: covid ===
# Classification Report after topic covid:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.93      0.93      1106
#          1.0       0.92      0.94      0.93      1006
#
#     accuracy                           0.93      2112
#    macro avg       0.93      0.93      0.93      2112
# weighted avg       0.93      0.93      0.93      2112
#
# Confusion Matrix after topic covid:
# [[1025   81]
#  [  64  942]]
#
# Weighted F1-score after topic covid: 0.9313664482352475
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.4845
# Evaluation on topic general: Weighted F1 = 0.3855
# Evaluation on topic covid: Weighted F1 = 0.9314
# Evaluation on topic syria: Weighted F1 = 0.5101
# Evaluation on topic islam: Weighted F1 = 0.3886
# Evaluation on topic notredame: Weighted F1 = 0.3419
# Evaluation on topic gossip: Weighted F1 = 0.4650
#
# === Phase 4: Training/Fine-tuning on topic: syria ===
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Classification Report after topic syria:
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.61      0.57        89
#          1.0       0.49      0.42      0.46        80
#
#     accuracy                           0.52       169
#    macro avg       0.52      0.52      0.51       169
# weighted avg       0.52      0.52      0.52       169
#
# Confusion Matrix after topic syria:
# [[54 35]
#  [46 34]]
#
# Weighted F1-score after topic syria: 0.516965739474774
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.4530
# Evaluation on topic general: Weighted F1 = 0.7731
# Evaluation on topic covid: Weighted F1 = 0.4655
# Evaluation on topic syria: Weighted F1 = 0.5170
# Evaluation on topic islam: Weighted F1 = 0.5146
# Evaluation on topic notredame: Weighted F1 = 0.5759
# Evaluation on topic gossip: Weighted F1 = 0.4987
#
# === Phase 5: Training/Fine-tuning on topic: islam ===
# Classification Report after topic islam:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.95      0.90        85
#          1.0       0.92      0.75      0.83        60
#
#     accuracy                           0.87       145
#    macro avg       0.88      0.85      0.86       145
# weighted avg       0.87      0.87      0.87       145
#
# Confusion Matrix after topic islam:
# [[81  4]
#  [15 45]]
#
# Weighted F1-score after topic islam: 0.8663353963446074
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.4439
# Evaluation on topic general: Weighted F1 = 0.9002
# Evaluation on topic covid: Weighted F1 = 0.4553
# Evaluation on topic syria: Weighted F1 = 0.3803
# Evaluation on topic islam: Weighted F1 = 0.8663
# Evaluation on topic notredame: Weighted F1 = 0.6322
# Evaluation on topic gossip: Weighted F1 = 0.3967
#
# === Phase 6: Training/Fine-tuning on topic: notredame ===
# Classification Report after topic notredame:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.91      0.87        68
#          1.0       0.83      0.70      0.76        43
#
#     accuracy                           0.83       111
#    macro avg       0.83      0.80      0.81       111
# weighted avg       0.83      0.83      0.83       111
#
# Confusion Matrix after topic notredame:
# [[62  6]
#  [13 30]]
#
# Weighted F1-score after topic notredame: 0.8254348001183444
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.5340
# Evaluation on topic general: Weighted F1 = 0.5555
# Evaluation on topic covid: Weighted F1 = 0.5681
# Evaluation on topic syria: Weighted F1 = 0.4010
# Evaluation on topic islam: Weighted F1 = 0.3882
# Evaluation on topic notredame: Weighted F1 = 0.8254
# Evaluation on topic gossip: Weighted F1 = 0.4695
#
# === Phase 7: Training/Fine-tuning on topic: gossip ===
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Classification Report after topic gossip:
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.68      0.62        50
#          1.0       0.61      0.50      0.55        50
#
#     accuracy                           0.59       100
#    macro avg       0.59      0.59      0.59       100
# weighted avg       0.59      0.59      0.59       100
#
# Confusion Matrix after topic gossip:
# [[34 16]
#  [25 25]]
#
# Weighted F1-score after topic gossip: 0.5866518802298619
#
# --- Evaluation on all topics ---
# Evaluation on topic politics: Weighted F1 = 0.5023
# Evaluation on topic general: Weighted F1 = 0.8742
# Evaluation on topic covid: Weighted F1 = 0.4439
# Evaluation on topic syria: Weighted F1 = 0.4011
# Evaluation on topic islam: Weighted F1 = 0.5747
# Evaluation on topic notredame: Weighted F1 = 0.4245
# Evaluation on topic gossip: Weighted F1 = 0.5867

# %%
# ---------------
# Results summary
# ---------------

print("\n=== Results Summary ===")
for topic, res in results.items():
    print(f"\nResults after training on topic {topic}:")
    for test_topic, f1 in res.items():
        print(f"  Test on topic {test_topic}: Weighted F1 = {f1:.4f}")
# Out:
# === Results Summary ===
#
# Results after training on topic politics:
#   Test on topic politics: Weighted F1 = 0.9346
#   Test on topic general: Weighted F1 = 0.3693
#   Test on topic covid: Weighted F1 = 0.3599
#   Test on topic syria: Weighted F1 = 0.5463
#   Test on topic islam: Weighted F1 = 0.4834
#   Test on topic notredame: Weighted F1 = 0.4718
#   Test on topic gossip: Weighted F1 = 0.3743
#
# Results after training on topic general:
#   Test on topic politics: Weighted F1 = 0.3690
#   Test on topic general: Weighted F1 = 0.9655
#   Test on topic covid: Weighted F1 = 0.3920
#   Test on topic syria: Weighted F1 = 0.3803
#   Test on topic islam: Weighted F1 = 0.4487
#   Test on topic notredame: Weighted F1 = 0.4654
#   Test on topic gossip: Weighted F1 = 0.4172
#
# Results after training on topic covid:
#   Test on topic politics: Weighted F1 = 0.4845
#   Test on topic general: Weighted F1 = 0.3855
#   Test on topic covid: Weighted F1 = 0.9314
#   Test on topic syria: Weighted F1 = 0.5101
#   Test on topic islam: Weighted F1 = 0.3886
#   Test on topic notredame: Weighted F1 = 0.3419
#   Test on topic gossip: Weighted F1 = 0.4650
#
# Results after training on topic syria:
#   Test on topic politics: Weighted F1 = 0.4530
#   Test on topic general: Weighted F1 = 0.7731
#   Test on topic covid: Weighted F1 = 0.4655
#   Test on topic syria: Weighted F1 = 0.5170
#   Test on topic islam: Weighted F1 = 0.5146
#   Test on topic notredame: Weighted F1 = 0.5759
#   Test on topic gossip: Weighted F1 = 0.4987
#
# Results after training on topic islam:
#   Test on topic politics: Weighted F1 = 0.4439
#   Test on topic general: Weighted F1 = 0.9002
#   Test on topic covid: Weighted F1 = 0.4553
#   Test on topic syria: Weighted F1 = 0.3803
#   Test on topic islam: Weighted F1 = 0.8663
#   Test on topic notredame: Weighted F1 = 0.6322
#   Test on topic gossip: Weighted F1 = 0.3967
#
# Results after training on topic notredame:
#   Test on topic politics: Weighted F1 = 0.5340
#   Test on topic general: Weighted F1 = 0.5555
#   Test on topic covid: Weighted F1 = 0.5681
#   Test on topic syria: Weighted F1 = 0.4010
#   Test on topic islam: Weighted F1 = 0.3882
#   Test on topic notredame: Weighted F1 = 0.8254
#   Test on topic gossip: Weighted F1 = 0.4695
#
# Results after training on topic gossip:
#   Test on topic politics: Weighted F1 = 0.5023
#   Test on topic general: Weighted F1 = 0.8742
#   Test on topic covid: Weighted F1 = 0.4439
#   Test on topic syria: Weighted F1 = 0.4011
#   Test on topic islam: Weighted F1 = 0.5747
#   Test on topic notredame: Weighted F1 = 0.4245
#   Test on topic gossip: Weighted F1 = 0.5867

# %% [markdown]
# ## VERSION 3: Dataset by Date

# %%
dataset_df = data_by_date()

for date, df in dataset_df.items():
    print(f"Date: {date}, Number of samples: {len(df)}")
# Out:
# /home/n.emmolo/progetto_tesi/src/utils.py:162: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   dfKaggleMeg['date'] = pd.to_datetime(dfKaggleMeg['date'], errors='coerce') # convert date column to datetime, coerce errors to NaT
# Date: 2011-2013, Number of samples: 55
# Date: 2014, Number of samples: 114
# Date: 2015, Number of samples: 84
# Date: 2016, Number of samples: 49687
# Date: 2017, Number of samples: 16657
# Date: 2020, Number of samples: 10559

# %%
# ------------------------------
# Fine-tuning on Dataset by Date
# ------------------------------

dataset_df = data_by_date()

datasets = {date: split_dataset(df) for date, df in dataset_df.items()} # split all datasets in train/val/test
model = build_model() # initialize model

results = {}

# sequential training
for i, (date, data) in enumerate(datasets.items()):
    print(f"\n=== Phase {i+1}: Training/Fine-tuning on date: {date} ===")
    
    X_train, y_train = data["train"]
    X_val, y_val = data["val"]
    X_test, y_test = data["test"]

    model.fit(pd.concat([X_train, X_val]), pd.concat([y_train, y_val])) # fine-tune on train + val

    y_pred = model.predict(X_test)
    print(f"Classification Report after date {date}:")
    print(classification_report(y_test, y_pred))
    print(f"Confusion Matrix after date {date}:")
    print(confusion_matrix(y_test, y_pred))
    print(f"\nWeighted F1-score after date {date}:", f1_score(y_test, y_pred, average="weighted"))


    # evaluation on all dates
    print("\n--- Evaluation on all dates ---")
    results[date] = {}
    for test_date, test_data in datasets.items(): # for each date
        X_te, y_te = test_data["test"]
        preds = model.predict(X_te)
        f1 = f1_score(y_te, preds, average="weighted")
        results[date][test_date] = f1
        print(f"Evaluation on date {test_date}: Weighted F1 = {f1:.4f}")
# Out:
# /home/n.emmolo/progetto_tesi/src/utils.py:162: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   dfKaggleMeg['date'] = pd.to_datetime(dfKaggleMeg['date'], errors='coerce') # convert date column to datetime, coerce errors to NaT
# === Phase 1: Training/Fine-tuning on date: 2011-2013 ===
# Classification Report after date 2011-2013:
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.40      0.40         5
#          1.0       0.50      0.50      0.50         6
#
#     accuracy                           0.45        11
#    macro avg       0.45      0.45      0.45        11
# weighted avg       0.45      0.45      0.45        11
#
# Confusion Matrix after date 2011-2013:
# [[2 3]
#  [3 3]]
#
# Weighted F1-score after date 2011-2013: 0.45454545454545453
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.4545
# Evaluation on date 2014: Weighted F1 = 0.3380
# Evaluation on date 2015: Weighted F1 = 0.3827
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Evaluation on date 2016: Weighted F1 = 0.6458
# Evaluation on date 2017: Weighted F1 = 0.7272
# Evaluation on date 2020: Weighted F1 = 0.3871
#
# === Phase 2: Training/Fine-tuning on date: 2014 ===
# Classification Report after date 2014:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        12
#          1.0       0.40      0.73      0.52        11
#
#     accuracy                           0.35        23
#    macro avg       0.20      0.36      0.26        23
# weighted avg       0.19      0.35      0.25        23
#
# Confusion Matrix after date 2014:
# [[ 0 12]
#  [ 3  8]]
#
# Weighted F1-score after date 2014: 0.2468443197755961
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.2338
# Evaluation on date 2014: Weighted F1 = 0.2468
# Evaluation on date 2015: Weighted F1 = 0.3992
# Evaluation on date 2016: Weighted F1 = 0.4278
# Evaluation on date 2017: Weighted F1 = 0.3039
# Evaluation on date 2020: Weighted F1 = 0.4082
#
# === Phase 3: Training/Fine-tuning on date: 2015 ===
# Classification Report after date 2015:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.38      0.43         8
#          1.0       0.55      0.67      0.60         9
#
#     accuracy                           0.53        17
#    macro avg       0.52      0.52      0.51        17
# weighted avg       0.52      0.53      0.52        17
#
# Confusion Matrix after date 2015:
# [[3 5]
#  [3 6]]
#
# Weighted F1-score after date 2015: 0.5193277310924369
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.3961
# Evaluation on date 2014: Weighted F1 = 0.3453
# Evaluation on date 2015: Weighted F1 = 0.5193
# Evaluation on date 2016: Weighted F1 = 0.4075
# Evaluation on date 2017: Weighted F1 = 0.8908
# Evaluation on date 2020: Weighted F1 = 0.3901
#
# === Phase 4: Training/Fine-tuning on date: 2016 ===
# Classification Report after date 2016:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      5306
#          1.0       0.99      0.99      0.99      4632
#
#     accuracy                           0.99      9938
#    macro avg       0.99      0.99      0.99      9938
# weighted avg       0.99      0.99      0.99      9938
#
# Confusion Matrix after date 2016:
# [[5247   59]
#  [  49 4583]]
#
# Weighted F1-score after date 2016: 0.9891333561597965
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.1818
# Evaluation on date 2014: Weighted F1 = 0.3843
# Evaluation on date 2015: Weighted F1 = 0.5882
# Evaluation on date 2016: Weighted F1 = 0.9891
# Evaluation on date 2017: Weighted F1 = 0.9931
# Evaluation on date 2020: Weighted F1 = 0.3075
#
# === Phase 5: Training/Fine-tuning on date: 2017 ===
# /home/n.emmolo/miniconda3/envs/env/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Classification Report after date 2017:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      3318
#          1.0       0.29      0.14      0.19        14
#
#     accuracy                           0.99      3332
#    macro avg       0.64      0.57      0.59      3332
# weighted avg       0.99      0.99      0.99      3332
#
# Confusion Matrix after date 2017:
# [[3313    5]
#  [  12    2]]
#
# Weighted F1-score after date 2017: 0.9940503071618532
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.2841
# Evaluation on date 2014: Weighted F1 = 0.6217
# Evaluation on date 2015: Weighted F1 = 0.3827
# Evaluation on date 2016: Weighted F1 = 0.3778
# Evaluation on date 2017: Weighted F1 = 0.9941
# Evaluation on date 2020: Weighted F1 = 0.3621
#
# === Phase 6: Training/Fine-tuning on date: 2020 ===
# Classification Report after date 2020:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92      1106
#          1.0       0.91      0.93      0.92      1006
#
#     accuracy                           0.92      2112
#    macro avg       0.92      0.92      0.92      2112
# weighted avg       0.92      0.92      0.92      2112
#
# Confusion Matrix after date 2020:
# [[1010   96]
#  [  70  936]]
#
# Weighted F1-score after date 2020: 0.9214354592989106
#
# --- Evaluation on all dates ---
# Evaluation on date 2011-2013: Weighted F1 = 0.2909
# Evaluation on date 2014: Weighted F1 = 0.3473
# Evaluation on date 2015: Weighted F1 = 0.4078
# Evaluation on date 2016: Weighted F1 = 0.4643
# Evaluation on date 2017: Weighted F1 = 0.3321
# Evaluation on date 2020: Weighted F1 = 0.9214

# %%
# ---------------
# Results summary
# ---------------

print("\n=== Results Summary ===")
for date, res in results.items():
    print(f"\nResults after training on date {date}:")
    for test_date, f1 in res.items():
        print(f"  Test on date {test_date}: Weighted F1 = {f1:.4f}")
# Out:
# === Results Summary ===
#
# Results after training on date 2011-2013:
#   Test on date 2011-2013: Weighted F1 = 0.4545
#   Test on date 2014: Weighted F1 = 0.3380
#   Test on date 2015: Weighted F1 = 0.3827
#   Test on date 2016: Weighted F1 = 0.6458
#   Test on date 2017: Weighted F1 = 0.7272
#   Test on date 2020: Weighted F1 = 0.3871
#
# Results after training on date 2014:
#   Test on date 2011-2013: Weighted F1 = 0.2338
#   Test on date 2014: Weighted F1 = 0.2468
#   Test on date 2015: Weighted F1 = 0.3992
#   Test on date 2016: Weighted F1 = 0.4278
#   Test on date 2017: Weighted F1 = 0.3039
#   Test on date 2020: Weighted F1 = 0.4082
#
# Results after training on date 2015:
#   Test on date 2011-2013: Weighted F1 = 0.3961
#   Test on date 2014: Weighted F1 = 0.3453
#   Test on date 2015: Weighted F1 = 0.5193
#   Test on date 2016: Weighted F1 = 0.4075
#   Test on date 2017: Weighted F1 = 0.8908
#   Test on date 2020: Weighted F1 = 0.3901
#
# Results after training on date 2016:
#   Test on date 2011-2013: Weighted F1 = 0.1818
#   Test on date 2014: Weighted F1 = 0.3843
#   Test on date 2015: Weighted F1 = 0.5882
#   Test on date 2016: Weighted F1 = 0.9891
#   Test on date 2017: Weighted F1 = 0.9931
#   Test on date 2020: Weighted F1 = 0.3075
#
# Results after training on date 2017:
#   Test on date 2011-2013: Weighted F1 = 0.2841
#   Test on date 2014: Weighted F1 = 0.6217
#   Test on date 2015: Weighted F1 = 0.3827
#   Test on date 2016: Weighted F1 = 0.3778
#   Test on date 2017: Weighted F1 = 0.9941
#   Test on date 2020: Weighted F1 = 0.3621
#
# Results after training on date 2020:
#   Test on date 2011-2013: Weighted F1 = 0.2909
#   Test on date 2014: Weighted F1 = 0.3473
#   Test on date 2015: Weighted F1 = 0.4078
#   Test on date 2016: Weighted F1 = 0.4643
#   Test on date 2017: Weighted F1 = 0.3321
#   Test on date 2020: Weighted F1 = 0.9214
